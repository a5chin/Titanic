# %% [markdown]
# # Analysis of Titanic

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %% [markdown]
# ## Read CSV Data

# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

# %% [markdown]
# ## Data

# %% [markdown]
# - Survived
#     - 0: dead
#     - 1: alive
# - Pclass (Grade of seat)
#     - 1: Upper
#     - 2: Middle
#     - 3: Lower
# - SibSp (Number of siblings/spouses riding with)
# - Parch (Number of parents/children riding with)
# - Ticket (Number of tickets)
# - Cabin (Room number)
# - Embarked (Place of departure)
#     - Cherbourg (France)
#     - Queenstown (New Zealand)
#     - Southampton (United Kingdom)

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
# ## Visualize Data

# %%
train['Sex'] = train.groupby('Sex').ngroup()
train['Embarked'] = train.groupby('Embarked').ngroup()
sns.pairplot(data=train.drop('PassengerId', axis=1), hue='Survived')

# %% [markdown]
# ## Research on data correlation

# %%
train.drop('PassengerId', axis=1).corr()
# Out:
#           Survived    Pclass       Sex       Age     SibSp     Parch  \
# Survived  1.000000 -0.338481 -0.543351 -0.077221 -0.035322  0.081629
# Pclass   -0.338481  1.000000  0.131900 -0.369226  0.083081  0.018443
# Sex      -0.543351  0.131900  1.000000  0.093254 -0.114631 -0.245489
# Age      -0.077221 -0.369226  0.093254  1.000000 -0.308247 -0.189119
# SibSp    -0.035322  0.083081 -0.114631 -0.308247  1.000000  0.414838
# Parch     0.081629  0.018443 -0.245489 -0.189119  0.414838  1.000000
# Fare      0.257307 -0.549500 -0.182333  0.096067  0.159651  0.216225
# Embarked -0.176509  0.173511  0.118492 -0.044830  0.071480  0.043351
#
#               Fare  Embarked
# Survived  0.257307 -0.176509
# Pclass   -0.549500  0.173511
# Sex      -0.182333  0.118492
# Age       0.096067 -0.044830
# SibSp     0.159651  0.071480
# Parch     0.216225  0.043351
# Fare      1.000000 -0.230365
# Embarked -0.230365  1.000000
